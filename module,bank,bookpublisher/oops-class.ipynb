# %%
import rectangle
import circle1
while(1):
    print("1.Rectangle\n2.Circle\n3.Exit")
    ch=int(input("Enter your choice:"))
    if ch==1:
        l=int(input("Enter length"))
        b=int(input("Enter breadth"))
        rectangle.rectarea(l,b)
        rectangle.rectperi(l,b)
    elif ch==2:
        r=int(input("Enter radius"))
        circle1.circlearea(r)
        circle1.circleperi(r)
    else:
        print("Exiting...")
        break
# Out:
# 1.Rectangle
# 2.Circle
# 3.Exit
# Enter your choice:1
# Enter length2
# Enter breadth6
# Area of rectangle: 12
# perimeter of rectangle: 16
# 1.Rectangle
# 2.Circle
# 3.Exit
# Enter your choice:2
# Enter radius6
# Area of circle: 113.03999999999999
# perimeter of circle: 37.68
# 1.Rectangle
# 2.Circle
# 3.Exit
# Enter your choice:3
# Exiting...

# %%
class bankaccount:
    def __init__(self,a_name,a_no,a_type,a_balance):
        self.acc_name=a_name
        self.acc_no=a_no
        self.acc_type=a_type
        self.acc_balance=a_balance
    def deposit(self,a_deposit):
        print("initial balance : ",self.acc_balance)
        self.acc_balance+=a_deposit
        print(a_deposit," is deposited")
        print("Current balance : ",self.acc_balance)
    def withdraw(self):
        self.amount=int(input("Withdraw the amount : "))
        print("Initial balance : ",self.acc_balance)
        if(self.amount>self.acc_balance):
            print("You don't have balance to withdraw ")
            print("current balance : ",self.acc_balance)
        else:
            print("Self amount is withdrawed")
            self.acc_balance=self.amount
            print("Current balance :",self.acc_balance)
    def acc_info(self):
        print("Account holder Name : ",self.acc_name)
        print("Account Number : ",self.acc_no)
        print("Account type : ",self.acc_type)
        print("Account Balance : ",self.acc_balance)
        
name=input("ENETER THE NAME : ")
no=int(input("Enter account number : "))
atype=input("Enter account type : ")
bal=int(input("Enter initial balance : "))
holder=bankaccount(name,no,atype,bal)

while(True):
    ch=int(input("1.Deposit 2.Withdraw  3.account info 4.Exit\n Choose your option : "))
    if ch==1:
        amount=int(input("Deposit amount : "))
        holder.deposit(amount)
    elif ch==2:
        holder.withdraw()
    elif ch==3:
        holder.acc_info()
    else:
        print("Exiting....")
        break
# Out:
# ENETER THE NAME : yadu
# Enter account number : 78542345
# Enter account type : sav
# Enter initial balance : 1000
# 1.Deposit 2.Withdraw  3.account info 4.Exit
#  Choose your option : 1
# Deposit amount : 100
# initial balance :  1000
# 100  is deposited
# Current balance :  1100
# 1.Deposit 2.Withdraw  3.account info 4.Exit
#  Choose your option : 3
# Account holder Name :  yadu
# Account Number :  78542345
# Account type :  sav
# Account Balance :  1100
# 1.Deposit 2.Withdraw  3.account info 4.Exit
#  Choose your option : 2
# Withdraw the amount : 1000
# Initial balance :  1100
# Self amount is withdrawed
# Current balance : 1000
# 1.Deposit 2.Withdraw  3.account info 4.Exit
#  Choose your option : 3
# Account holder Name :  yadu
# Account Number :  78542345
# Account type :  sav
# Account Balance :  1000
# 1.Deposit 2.Withdraw  3.account info 4.Exit
#  Choose your option : 4
# Exiting....

# %%
class publisher:
    def __init__(self,pname):
        self.pubname=pname
    def display1(self):
        print("Book details \nPublisher name=",self.pubname)
class book(publisher):
    def __init__(self,pname,bname,author):
        self.title=bname
        self.auth=author
        publisher.__init__(self,pname)
    def display2(self):
        print("Title=",self.title)
        print("Author",self.auth)
class python(book):
    def __init__(self,pname,title,au,price,np):
        self.rate=price
        self.nop=np
        book.__init__(self,pname,title,au)
    def display3(self):
        print("Rate=",self.rate)
        print("No of pages=",self.nop)
p=input("Enter publisher name: ")
b=input("Enter book name: ")
a=input("Enter author name: ")
r=int(input("Enter rate of book: "))
n=int(input("Enter no. of pages: "))
a=python(p,b,a,r,n)
a.display1()
a.display2()
a.display3()
# Out:
# Enter publisher name: DC Comics
# Enter book name: BATMAN
# Enter author name: future Batman
# Enter rate of book: 1000
# Enter no. of pages: 100
# Book details
#  Publisher name= DC Comics
# Title= BATMAN
# Author future Batman
# Rate= 1000
# No of pages= 100
